# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Read the Data

# %%
dataframe_QB = pd.read_excel("../final_dataset.xltx", sheet_name="QB")
dataframe_RB = pd.read_excel("../final_dataset.xltx", sheet_name="RB")
dataframe_WR = pd.read_excel("../final_dataset.xltx", sheet_name="WR")

dataframe_QB_carrer_earnings = pd.read_excel("../career_earnings_QB.xltx")
dataframe_RB_carrer_earnings = pd.read_excel("../career_earnings_RB.xltx")
dataframe_WR_carrer_earnings = pd.read_excel("../career_earnings_WR.xltx")

# %%
dataframe_QB = dataframe_QB.merge(dataframe_QB_carrer_earnings[['Player', 'Cap-Inflated Earnings']], on="Player", how="left")
dataframe_RB = dataframe_RB.merge(dataframe_RB_carrer_earnings[['Player', 'Cap-Inflated Earnings']], on="Player", how="left")
dataframe_WR = dataframe_WR.merge(dataframe_WR_carrer_earnings[['Player', 'Cap-Inflated Earnings']], on="Player", how="left")

# %%
dataframe_WR["Yds"] = dataframe_WR["Yds.1"]
dataframe_RB["Yds"] = dataframe_RB["Yds.1"]
dataframe_QB["Yds"] = dataframe_QB["Yds.1"]

dataframe_RB = dataframe_RB.drop(["Yds.1"], axis=1)
dataframe_WR = dataframe_WR.drop(["Yds.1"], axis=1)
dataframe_QB = dataframe_QB.drop(["Yds.1"], axis=1)

# %% [markdown]
# ## Transfrom the Data

# %%
dataframe_QB['Performance-Index'] = (dataframe_QB['Yds'] /  dataframe_QB['Yds'].max()) * 50 + (dataframe_QB['TD'] /  dataframe_QB['TD'].max()) * 50
dataframe_RB['Performance-Index'] = (dataframe_RB['Yds'] /  dataframe_RB['Yds'].max()) * 50 + (dataframe_RB['TD'] /  dataframe_RB['TD'].max()) * 50
dataframe_WR['Performance-Index'] = (dataframe_WR['Yds'] /  dataframe_WR['Yds'].max()) * 50 + (dataframe_WR['TD'] /  dataframe_WR['TD'].max()) * 50

# %%
dataframe_QB
# Out:
#              Player    Yds  Round  Pick  Draft Year    To    G   GS   TD  \
# 0         Tom Brady  89214      6   199        2000  2022  335  333  649
# 1        Drew Brees  80358      2    32        2001  2020  287  286  571
# 2    Peyton Manning  71940      1     1        1998  2015  266  265  539
# 3       Brett Favre  71838      2    33        1991  2010  302  298  508
# 4     Aaron Rodgers  66274      1    24        2005  2025  264  257  527
# ..              ...    ...    ...   ...         ...   ...  ...  ...  ...
# 245   Scott Brunner   6457      6   145        1980  1985   73   30   29
# 246     Hugh Millen   6440      3    71        1986  1995   40   25   22
# 247    Steve Ramsey   6437      5   126        1970  1976   54   31   35
# 248      Jim Miller   6387      6   178        1994  2002   37   27   36
# 249       Drew Lock   6369      2    42        2019  2025   41   28   34
#
#      Seasons in the NFL Pos Cap-Inflated Earnings  Performance-Index
# 0                    23  QB          $708,165,480         100.000000
# 1                    20  QB          $606,300,629          89.027408
# 2                    18  QB          $761,097,143          81.844208
# 3                    20  QB          $580,376,675          79.398752
# 4                    21  QB          $704,306,889          77.744198
# ..                  ...  ..                   ...                ...
# 245                   6  QB                   NaN           5.853033
# 246                  10  QB                   NaN           5.304214
# 247                   7  QB                   NaN           6.304074
# 248                   9  QB                   NaN           6.353093
# 249                   7  QB           $25,210,866           6.188922
#
# [250 rows x 13 columns]

# %%
dataframe_RB
# Out:
#                  Player    Yds  Round  Pick  Draft Year    To    G   GS   TD  \
# 0          Emmitt Smith  18355      1    17        1990  2004  226  219  164
# 1         Walter Payton  16726      1     4        1975  1987  190  184  110
# 2            Frank Gore  16000      3    65        2005  2020  241  218   81
# 3         Barry Sanders  15269      1     3        1989  1998  153  151   99
# 4       Adrian Peterson  14918      1     7        2007  2021  184  167  120
# ..                  ...    ...    ...   ...         ...   ...  ...  ...  ...
# 246         Don Calhoun   3559     10   249        1974  1982  114   50   23
# 247  Kenneth Walker III   3555      2    41        2022  2025   58   54   29
# 248      Darren Sproles   3552      4   130        2005  2019  183   31   23
# 249         Tony Nathan   3543      3    61        1979  1987  123   63   16
# 250       Sherman Smith   3520      2    58        1976  1983   95   70   28
#
#     Pos  Seasons in the NFL Cap-Inflated Earnings  Performance-Index
# 0    RB                  15          $267,758,332         100.000000
# 1    RB                  13                   NaN          79.099102
# 2    RB                  16          $147,956,622          68.279976
# 3    RB                  10          $183,424,034          71.776498
# 4    RB                  15          $236,878,277          77.222794
# ..   ..                 ...                   ...                ...
# 246  RB                   9                   NaN          16.707101
# 247  RB                   4           $24,019,497          18.525473
# 248  RB                  15          $101,311,380          16.688033
# 249  RB                   9                   NaN          14.529370
# 250  RB                   8                   NaN          18.125253
#
# [251 rows x 13 columns]

# %%
dataframe_WR
# Out:
#                 Player    Yds  Round  Pick  Draft Year    To    G   GS   TD  \
# 0           Jerry Rice  22895      1    16        1985  2004  303  284  197
# 1     Larry Fitzgerald  17492      1     3        2004  2020  263  261  121
# 2        Terrell Owens  15934      3    89        1996  2010  219  201  153
# 3           Randy Moss  15292      1    21        1998  2012  218  193  156
# 4          Isaac Bruce  15208      2    33        1994  2009  223  201   91
# ..                 ...    ...    ...   ...         ...   ...  ...  ...  ...
# 248     Bill Schroeder   4583      6   181        1994  2004  111   78   28
# 249   Courtney Hawkins   4573      2    44        1992  2000  131   81   18
# 250  Antwaan Randle El   4467      2    62        2002  2010  143   71   15
# 251     Darius Slayton   4435      5   171        2019  2025  106   78   22
# 252    Michael Jenkins   4427      1    29        2004  2012  130   79   25
#
#     Pos  Seasons in the NFL Cap-Inflated Earnings  Performance-Index
# 0    WR                  20          $184,800,205         100.000000
# 1    WR                  17          $425,891,097          68.911140
# 2    WR                  15                   NaN          73.630478
# 3    WR                  15          $288,943,873          72.989847
# 4    WR                  16                   NaN          56.308939
# ..   ..                 ...                   ...                ...
# 248  WR                  11                   NaN          17.115335
# 249  WR                   9                   NaN          14.555425
# 250  WR                   9                   NaN          13.562512
# 251  WR                   7           $34,076,129          15.269277
# 252  WR                   9           $57,633,060          16.013227
#
# [253 rows x 13 columns]

# %% [markdown]
# ## Plot the data

# %%
joined_datas = pd.concat([dataframe_QB, dataframe_RB, dataframe_WR])

joined_datas = joined_datas[joined_datas['Draft Year'] >= 1978]

joined_datas["Cap-Inflated Earnings"] = joined_datas["Cap-Inflated Earnings"].str.replace("$", "", regex=False)\
                           .str.replace(",", "", regex=False)\
                           .astype(float)

# %%
joined_datas
# Out:
#                 Player    Yds  Round  Pick  Draft Year    To    G   GS   TD  \
# 0            Tom Brady  89214      6   199        2000  2022  335  333  649
# 1           Drew Brees  80358      2    32        2001  2020  287  286  571
# 2       Peyton Manning  71940      1     1        1998  2015  266  265  539
# 3          Brett Favre  71838      2    33        1991  2010  302  298  508
# 4        Aaron Rodgers  66274      1    24        2005  2025  264  257  527
# ..                 ...    ...    ...   ...         ...   ...  ...  ...  ...
# 248     Bill Schroeder   4583      6   181        1994  2004  111   78   28
# 249   Courtney Hawkins   4573      2    44        1992  2000  131   81   18
# 250  Antwaan Randle El   4467      2    62        2002  2010  143   71   15
# 251     Darius Slayton   4435      5   171        2019  2025  106   78   22
# 252    Michael Jenkins   4427      1    29        2004  2012  130   79   25
#
#      Seasons in the NFL Pos  Cap-Inflated Earnings  Performance-Index
# 0                    23  QB            708165480.0         100.000000
# 1                    20  QB            606300629.0          89.027408
# 2                    18  QB            761097143.0          81.844208
# 3                    20  QB            580376675.0          79.398752
# 4                    21  QB            704306889.0          77.744198
# ..                  ...  ..                    ...                ...
# 248                  11  WR                    NaN          17.115335
# 249                   9  WR                    NaN          14.555425
# 250                   9  WR                    NaN          13.562512
# 251                   7  WR             34076129.0          15.269277
# 252                   9  WR             57633060.0          16.013227
#
# [568 rows x 13 columns]

# %%
plt.scatter(joined_datas['Seasons in the NFL'], joined_datas['Performance-Index'])
plt.xlabel("Season in the NFL")
plt.ylabel("Performance Index")
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
plt.scatter(joined_datas['Seasons in the NFL'], joined_datas['Cap-Inflated Earnings'])
plt.xlabel("Season in the NFL")
plt.ylabel('Cap-Inflated Earnings')
# Out:
# Text(0, 0.5, 'Cap-Inflated Earnings')

# %%
plt.scatter(joined_datas['Performance-Index'], joined_datas['Cap-Inflated Earnings'])
plt.xlabel("'Performance-Index'")
plt.ylabel('Cap-Inflated Earnings')
# Out:
# Text(0, 0.5, 'Cap-Inflated Earnings')

# %%
plt.scatter(joined_datas['Pick'], joined_datas['Cap-Inflated Earnings'])
plt.xlabel("'Pick'")
plt.ylabel('Cap-Inflated Earnings')
# Out:
# Text(0, 0.5, 'Cap-Inflated Earnings')

# %%
plt.scatter(joined_datas['Pick'], joined_datas['Performance-Index'])
plt.xlabel('Pick')
plt.ylabel('Performance-Index')
# Out:
# Text(0, 0.5, 'Performance-Index')

# %%
plt.scatter(joined_datas['Seasons in the NFL'], joined_datas['Pick'])
plt.xlabel('Seasons in the NFL')
plt.ylabel('Pick')
# Out:
# Text(0, 0.5, 'Pick')

# %%
plt.bar(np.unique(joined_datas[joined_datas['Pos'] == 'QB']['Round']), np.unique(joined_datas[joined_datas['Pos'] == 'QB']['Round'], return_counts=True)[1])
# Out:
# <BarContainer object of 12 artists>

# %%
pip install tigramite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tigramite
#   Downloading tigramite-5.2.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.18 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tigramite) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tigramite) (1.15.3)
# Requirement already satisfied: six in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tigramite) (1.16.0)
# Downloading tigramite-5.2.10.1-py3-none-any.whl (314 kB)
# Installing collected packages: tigramite
# Successfully installed tigramite-5.2.10.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\balin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tigramite
from tigramite import data_processing as dp
from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests.regressionCI import RegressionCI

selected_columns = [
    'Pick', 
    'Pos', 
    'Seasons in the NFL', 
    'Cap-Inflated Earnings', 
    'Performance-Index'
]

df_filtered = joined_datas[selected_columns].dropna().copy()

if df_filtered['Pos'].dtype == 'object':
    df_filtered['Pos'] = df_filtered['Pos'].astype('category').cat.codes
    
#if df_filtered['Round'].dtype == 'object':
#  df_filtered['Round'] = df_filtered['Round'].astype('category').cat.codes

data_array = df_filtered.values
var_names = list(df_filtered.columns)
T_len = len(df_filtered)

# datatype masking
data_type_matrix = np.zeros(data_array.shape, dtype='int')

# column with index 1 is discrete (1) and not continous (0)
data_type_matrix[:, 1] = 1
#data_type_matrix[:, 0] = 1


#TIGRAMITE DATAFRAME
tigramite_df = dp.DataFrame(
    data_array,
    data_type=data_type_matrix,  
    var_names=var_names
)

regressionCI = RegressionCI(significance='analytic')

pcmci = PCMCI(
    dataframe=tigramite_df, 
    cond_ind_test=regressionCI
)

results = pcmci.run_pcmci(tau_min=0, tau_max=0, pc_alpha=0.2, alpha_level=0.01)

val_matrix = results['val_matrix']
val_matrix /= (2. * T_len)

tp.plot_graph(
    val_matrix=val_matrix,
    graph=results['graph'],
    var_names=var_names,
    figsize=(10, 8),
    node_size=0.18,
    node_label_size=12,
    link_colorbar_label='cross-MCI (Normalized)',
    node_colorbar_label='auto-MCI',
    vmin_edges=0.,
    vmax_edges=0.1,
    edge_ticks=0.05,
    cmap_edges='OrRd',
    vmin_nodes=0,
    vmax_nodes=0.5,
    node_ticks=0.1,
    cmap_nodes='OrRd',
)

plt.show()

# %%
from tigramite.independence_tests.parcorr import ParCorr

selected_columns = [
    'Pick', 
    'Pos',                  
    'Seasons in the NFL', 
    'Cap-Inflated Earnings', 
    'Performance-Index'
]

df_filtered = joined_datas[selected_columns].dropna().copy()

# one_hot coding, new columns are: Pos_QB, Pos_RB etc.
df_encoded = pd.get_dummies(df_filtered, columns=['Pos'], dtype=int)

var_names = list(df_encoded.columns)
data_array = df_encoded.values
T_len = len(df_encoded)  

# simple dataframe because the parr_corr doesn't need else
tigramite_df = dp.DataFrame(data_array, var_names=var_names)

# using parrcorr test
parcorr = ParCorr(significance='analytic')

pcmci = PCMCI(dataframe=tigramite_df, cond_ind_test=parcorr)
results = pcmci.run_pcmci(tau_min=1, tau_max=2, pc_alpha=0.2, alpha_level=0.01)

#normalize the test statistics
val_matrix_normalized = results['val_matrix'] / (2. * T_len)

max_val = np.max(np.abs(val_matrix_normalized))
if max_val == 0: max_val = 0.01 
    

tp.plot_graph(
    val_matrix=val_matrix_normalized,
    graph=results['graph'],
    var_names=var_names,
    figsize=(12, 10),
    node_size=0.15,
    node_label_size=11,
    link_colorbar_label='cross-MCI (Normalized)',
    node_colorbar_label='auto-MCI',
    
   
    vmin_edges=0.,
    vmax_edges=max_val,             
    edge_ticks=max_val / 2.,
    cmap_edges='coolwarm',          
    
    vmin_nodes=0,
    vmax_nodes=0.5,
    node_ticks=0.1,
    cmap_nodes='OrRd',
)

plt.show()

# %%
pip install causal-learn lingam
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting causal-learn
#   Downloading causal_learn-0.1.4.7-py3-none-any.whl.metadata (4.8 kB)
# Collecting lingam
#   Downloading lingam-1.12.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (1.6.1)
# Collecting graphviz (from causal-learn)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting statsmodels (from causal-learn)
#   Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: pandas in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (3.8.4)
# Requirement already satisfied: networkx in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (3.5)
# Collecting pydot (from causal-learn)
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (4.66.4)
# Collecting momentchi2 (from causal-learn)
#   Downloading momentchi2-0.1.8-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: joblib in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from causal-learn) (1.5.1)
# Collecting pygam (from lingam)
#   Downloading pygam-0.12.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting psy (from lingam)
#   Downloading psy-0.0.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting semopy (from lingam)
#   Downloading semopy-2.3.11.tar.gz (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      -------------------------------------- - 1.6/1.6 MB 7.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting autograd (from lingam)
#   Downloading autograd-1.8.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->causal-learn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->causal-learn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->causal-learn) (2024.2)
# Collecting progressbar2 (from psy->lingam)
#   Downloading progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->causal-learn) (3.6.0)
# Requirement already satisfied: sympy in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from semopy->lingam) (1.13.1)
# Collecting numdifftools (from semopy->lingam)
#   Downloading numdifftools-0.9.42-py3-none-any.whl.metadata (10 kB)
# Collecting patsy>=0.5.6 (from statsmodels->causal-learn)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: colorama in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->causal-learn) (0.4.6)
# Collecting python-utils>=3.8.1 (from progressbar2->psy->lingam)
#   Downloading python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->causal-learn) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy->semopy->lingam) (1.3.0)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\users\balin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-utils>=3.8.1->progressbar2->psy->lingam) (4.13.2)
# Downloading causal_learn-0.1.4.7-py3-none-any.whl (245 kB)
# Downloading lingam-1.12.2-py3-none-any.whl (145 kB)
# Downloading autograd-1.8.0-py3-none-any.whl (51 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading momentchi2-0.1.8-py3-none-any.whl (11 kB)
# Downloading psy-0.0.1-py2.py3-none-any.whl (38 kB)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Downloading pygam-0.12.0-py3-none-any.whl (84 kB)
# Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.5 MB 11.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 10.2 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading progressbar2-4.5.0-py3-none-any.whl (57 kB)
# Downloading numdifftools-0.9.42-py3-none-any.whl (94 kB)
# Downloading python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: semopy
#   Building wheel for semopy (setup.py): started
#   Building wheel for semopy (setup.py): finished with status 'done'
#   Created wheel for semopy: filename=semopy-2.3.11-py3-none-any.whl size=1659707 sha256=769dcb92ee2b6615714376b16d77eada6bffca92f0dfb998accd39462d423508
#   Stored in directory: c:\users\balin\appdata\local\pip\cache\wheels\c6\24\8b\be911b059a61f490f38425eb19bf2fed470a5ead97228e8255
# Successfully built semopy
# Installing collected packages: python-utils, pydot, patsy, graphviz, autograd, progressbar2, numdifftools, momentchi2, statsmodels, pygam, psy, semopy, causal-learn, lingam
# Successfully installed autograd-1.8.0 causal-learn-0.1.4.7 graphviz-0.21 lingam-1.12.2 momentchi2-0.1.8 numdifftools-0.9.42 patsy-1.0.2 progressbar2-4.5.0 psy-0.0.1 pydot-4.0.1 pygam-0.12.0 python-utils-3.9.1 semopy-2.3.11 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\balin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from scipy import stats
 
 
selected_columns = [
    'Pick',
    'Pos',
    'Seasons in the NFL',
    'Cap-Inflated Earnings',
    'Performance-Index'
]
 
# 2) Encoding Pos - SINGLE categorical column and NOT one-hot!
#The one-hot encoded Pos_QB/Pos_RB/Pos_WR columns are deterministically
#interdependent (Pos_QB + Pos_RB + Pos_WR = 1 at all times), which is why the PC
# algorithm finds "false" values among them—this is not a causal discovery, but
# a tautology resulting from the encoding. We use a single category-coded column instead.

df_model = df_filtered.copy()
pos_categories = df_model['Pos'].astype('category')
df_model['Pos_code'] = pos_categories.cat.codes
pos_mapping = dict(enumerate(pos_categories.cat.categories))
print("Pos_code <-> Pos mapping:", pos_mapping)
df_model = df_model.drop(columns=['Pos'])
 
var_names = df_model.columns.tolist()
 
# 3) METHOD A: PC algorithm, Fisher-Z test
#This is the standard choice for cross-sectional data. tt returns a CPDAG:
#some edges may remain OPEN if they cannot be unambiguously identified from the data
#(this is NOT an error—it is a theoretical limitation as with Tigramite as well I guess).

from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.cit import fisherz
 
data_pc = df_model.values.astype(float)
cg = pc(data_pc, alpha=0.05, indep_test=fisherz, node_names=var_names, show_progress=False)
 
print("\nPC algorithm (Fisher-Z, alpha=0.05")
print("pointed edges (-->) and non-pointed edges (---):")
for edge in cg.G.get_graph_edges():
    print(" ", edge)
 
# 4) METHOD B: DirectLiNGAM - fully directed graph
#LiNGAM assumes a linear model and non-Gaussian noise; in this case, all
#directions are theoretically identifiable (no unobserved variables remain). Since the continuous
#variables exhibit strong right-skewness it's advisable to apply a log1p
#transformation on the Cap-Inflated Earnings and Performance-Index
#columns—otherwise the superstar distribution (like Tom Brady level earnings)
#skews the direction estimate in the OPPOSITE direction of expectations.

import lingam
 
print("\nskewness-check the reason to transform")
for col in ['Pick', 'Seasons in the NFL', 'Cap-Inflated Earnings', 'Performance-Index']:
    print(f"  {col}: skew={stats.skew(df_model[col]):.2f}")
 
df_lingam = df_model.copy()
df_lingam['Cap-Inflated Earnings'] = np.log1p(df_lingam['Cap-Inflated Earnings'])
df_lingam['Performance-Index'] = np.log1p(df_lingam['Performance-Index'])
 
X = df_lingam.values.astype(float)
X_std = (X - X.mean(axis=0)) / X.std(axis=0)
 
model = lingam.DirectLiNGAM()
model.fit(X_std)
 
print("\nCausal order (up -> down stream):")
print([var_names[i] for i in model.causal_order_])
 
adj = model.adjacency_matrix_
print("\nedges with non-null coeffs:")
for i, effect in enumerate(var_names):
    for j, cause in enumerate(var_names):
        if abs(adj[i, j]) > 1e-6:
            print(f"  {cause} --> {effect}   (coef={adj[i, j]:.3f})")
 
# 5)how stable is the direction estimate?
#We check whether the above peaks are
#random by resampling multiple times. A frequency of 90%+ is considered stable.
print("\nIs stable, 200 sample ===")
result = model.bootstrap(X_std, n_sampling=200)
cdc = result.get_causal_direction_counts(n_directions=8, min_causal_effect=0.05)
for i in range(len(cdc['from'])):
    a = var_names[cdc['from'][i]]
    b = var_names[cdc['to'][i]]
    cnt = cdc['count'][i]
    print(f"  {a} --> {b} : {cnt}/200 ({cnt/200*100:.0f}%)")

# 6) Visualization - networkx + matplotlib (DOES NOT require Graphviz/dot to be installed)
# Note: causal-learn's own GraphUtils.to_pydot() function uses the
# system-level Graphviz "dot" binary, which on Windows is typically
# not installed or in the PATH (resulting in a "dot not found in path" error). The solution below
# relies solely on already installed Python packages (networkx, matplotlib).
import networkx as nx
import matplotlib.pyplot as plt
 
n = len(var_names)
mat = cg.G.graph  # causal-learn adjacency: mat[i,j]==-1 & mat[j,i]==1 -> i --> j
 
G_directed = nx.DiGraph()
G_directed.add_nodes_from(var_names)
undirected_edges = []
 
for i in range(n):
    for j in range(n):
        if i >= j:
            continue
        a, b = mat[i, j], mat[j, i]
        if a == -1 and b == 1:
            G_directed.add_edge(var_names[i], var_names[j])
        elif a == 1 and b == -1:
            G_directed.add_edge(var_names[j], var_names[i])
        elif a == -1 and b == -1:
            undirected_edges.append((var_names[i], var_names[j]))
 
pos = nx.spring_layout(G_directed, seed=42, k=1.8)
fig, ax = plt.subplots(figsize=(9, 7))
node_size = 3500
 
nx.draw_networkx_nodes(G_directed, pos, node_color='#cfe8ff', node_size=node_size,
                        edgecolors='#333', linewidths=1.2, ax=ax)
nx.draw_networkx_labels(G_directed, pos, font_size=10, ax=ax)
 
# Guided arrows: thick black arrows with clearly visible arrowheads
nx.draw_networkx_edges(
    G_directed, pos, edgelist=list(G_directed.edges()),
    node_size=node_size, arrowstyle='-|>', arrowsize=35,
    width=2.0, edge_color='black',
    min_source_margin=15, min_target_margin=15, ax=ax
)
 
# Non-directional arrows: a dashed gray line without an arrowhead
nx.draw_networkx_edges(
    G_directed, pos, edgelist=undirected_edges, node_size=node_size,
    arrows=False, style='dashed', width=1.5, edge_color='gray', ax=ax
)
 
ax.set_axis_off()
plt.tight_layout()
plt.savefig('pc_graph.png', dpi=150, bbox_inches='tight')
print("\nPC graf elmentve: pc_graph.png")
print("Iranyitott elek:", list(G_directed.edges()))
print("Iranyitatlan elek:", undirected_edges)
# Out:
# Pos_code <-> Pos mapping: {0: 'FB', 1: 'QB', 2: 'RB', 3: 'WR'}
#
# PC algorithm (Fisher-Z, alpha=0.05
# pointed edges (-->) and non-pointed edges (---):
#   Pick --> Cap-Inflated Earnings
#   Seasons in the NFL --> Cap-Inflated Earnings
#   Seasons in the NFL --- Performance-Index
#   Performance-Index --> Cap-Inflated Earnings
#   Pos_code --> Cap-Inflated Earnings
#
# skewness-check the reason to transform
#   Pick: skew=1.57
#   Seasons in the NFL: skew=0.65
#   Cap-Inflated Earnings: skew=2.08
#   Performance-Index: skew=1.31
#
# Causal order (up -> down stream):
# ['Pos_code', 'Pick', 'Seasons in the NFL', 'Performance-Index', 'Cap-Inflated Earnings']
#
# edges with non-null coeffs:
#   Pick --> Cap-Inflated Earnings   (coef=-0.140)
#   Seasons in the NFL --> Cap-Inflated Earnings   (coef=0.296)
#   Performance-Index --> Cap-Inflated Earnings   (coef=0.223)
#   Pick --> Performance-Index   (coef=-0.160)
#   Seasons in the NFL --> Performance-Index   (coef=0.615)
#   Pos_code --> Performance-Index   (coef=0.289)
#
# Is stable, 200 sample ===
#   Seasons in the NFL --> Cap-Inflated Earnings : 200/200 (100%)
#   Performance-Index --> Cap-Inflated Earnings : 182/200 (91%)
#   Seasons in the NFL --> Performance-Index : 179/200 (90%)
#   Pick --> Cap-Inflated Earnings : 138/200 (69%)
#   Pos_code --> Performance-Index : 131/200 (66%)
#   Pick --> Performance-Index : 120/200 (60%)
#   Pos_code --> Cap-Inflated Earnings : 72/200 (36%)
#   Performance-Index --> Pos_code : 69/200 (34%)
#
# PC graf elmentve: pc_graph.png
# Iranyitott elek: [('Pick', 'Cap-Inflated Earnings'), ('Seasons in the NFL', 'Cap-Inflated Earnings'), ('Performance-Index', 'Cap-Inflated Earnings'), ('Pos_code', 'Cap-Inflated Earnings')]
# Iranyitatlan elek: [('Seasons in the NFL', 'Performance-Index')]
