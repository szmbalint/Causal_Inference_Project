# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.9 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.9 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/9.9 MB 3.5 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 3.6 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 3.7 MB/s  0:00:03
# Downloading numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.5 MB 8.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.5 MB 4.5 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.5 MB 4.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/12.5 MB 4.6 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.5 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.5 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.5 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.5 MB 4.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.5 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.5 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 4.8 MB/s  0:00:02
# Installing collected packages: numpy, pandas
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed numpy-2.4.6 pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 14.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.3 MB 3.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.3 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.3 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.3 MB 4.5 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 4.8 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.9 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/7.2 MB 5.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 4.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.2 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 5.1 MB/s  0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\balin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the Data

# %%
dataframe_QB_Passing_yards = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_passing_yards")
dataframe_QB_Passing_TDS = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_TDs")
dataframe_RB_Rushing_Yards = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_Rushing_yards")
dataframe_RB_Rushing_TDS = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_Rushing_TDS")
dataframe_WR_Rushing_Yards = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_Recieving_Yards")
dataframe_WR_Rushing_TDS = pd.read_excel("../Player_Stats.xltx", sheet_name="Career_Recieving_TDS")

# %% [markdown]
# ## Adapt the Data

# %% [markdown]
# ## Add the amount of Seasons in the NFL

# %%
dataframe_RB_Rushing_Yards['Seasons in the NFL'] = [int(dataframe_RB_Rushing_Yards['Years'][i].split('-')[1]) - int(dataframe_RB_Rushing_Yards['Years'][i].split('-')[0]) + 1 for i in range(len(dataframe_RB_Rushing_Yards['Years']))]
dataframe_WR_Rushing_Yards['Seasons in the NFL'] = [int(dataframe_WR_Rushing_Yards['Years'][i].split('-')[1]) - int(dataframe_WR_Rushing_Yards['Years'][i].split('-')[0]) + 1 for i in range(len(dataframe_WR_Rushing_Yards['Years']))]

# %%
dataframe_RB_Rushing_Yards.head()
dataframe_WR_Rushing_Yards.head()
# Out:
#               Player    Yds      Years  Seasons in the NFL
# 0        Jerry Rice+  22895  1985-2004                  20
# 1  Larry Fitzgerald+  17492  2004-2020                  17
# 2     Terrell Owens+  15934  1996-2010                  15
# 3        Randy Moss+  15292  1998-2012                  15
# 4       Isaac Bruce+  15208  1994-2009                  16

# %%
dataframe_QB_Passing_yards['Seasons in the NFL'] = dataframe_QB_Passing_yards['Sessions in NFL']

# %%
dataframe_QB_Passing_yards
# Out:
#               Player    Yds  year of draft  Unnamed: 3  Sessions in NFL  \
# 0          Tom Brady  89214           2000        2022               23
# 1        Drew Brees+  80358           2001        2020               20
# 2    Peyton Manning+  71940           1998        2015               18
# 3       Brett Favre+  71838           1991        2010               20
# 4      Aaron Rodgers  66274           2005        2025               21
# ..               ...    ...            ...         ...              ...
# 245         Al Dorow   7708           1954        1962                9
# 246           Bo Nix   7706           2024        2025                2
# 247   Craig Erickson   7625           1992        1997                6
# 248       Matt Moore   7597           2007        2019               13
# 249   Caleb Williams   7483           2024        2025                2
#
#      Seasons in the NFL
# 0                    23
# 1                    20
# 2                    18
# 3                    20
# 4                    21
# ..                  ...
# 245                   9
# 246                   2
# 247                   6
# 248                  13
# 249                   2
#
# [250 rows x 6 columns]

# %%
dataframe_QB_Passing_yards = dataframe_QB_Passing_yards.drop("Sessions in NFL", axis=1)

# %% [markdown]
# ## Join the data

# %%
joined_QB_data = dataframe_QB_Passing_yards.merge(dataframe_QB_Passing_TDS, on="Player")
joined_RB_data = dataframe_RB_Rushing_Yards.merge(dataframe_RB_Rushing_TDS, on="Player")
joined_WR_data = dataframe_WR_Rushing_Yards.merge(dataframe_WR_Rushing_TDS, on="Player")

# %%
joined_QB_data.head()
# Out:
#             Player    Yds  year of draft  Unnamed: 3  Seasons in the NFL  TDs  \
# 0        Tom Brady  89214           2000        2022                  23  649
# 1      Drew Brees+  80358           2001        2020                  20  571
# 2  Peyton Manning+  71940           1998        2015                  18  539
# 3     Brett Favre+  71838           1991        2010                  20  508
# 4    Aaron Rodgers  66274           2005        2025                  21  527
#
#        Years
# 0  2000-2022
# 1  2001-2020
# 2  1998-2015
# 3  1991-2010
# 4  2005-2025

# %%
joined_RB_data.head()
# Out:
#             Player    Yds    Years_x  Seasons in the NFL   TD    Years_y
# 0    Emmitt Smith+  18355  1990-2004                  15  164  1990-2004
# 1   Walter Payton+  16726  1975-1987                  13  110  1975-1987
# 2       Frank Gore  16000  2005-2020                  16   81  2005-2020
# 3   Barry Sanders+  15269  1989-1998                  10   99  1989-1998
# 4  Adrian Peterson  14918  2007-2021                  15  120  2007-2021

# %%
joined_WR_data.head()
# Out:
#               Player    Yds    Years_x  Seasons in the NFL   TD    Years_y
# 0        Jerry Rice+  22895  1985-2004                  20  197  1985-2004
# 1  Larry Fitzgerald+  17492  2004-2020                  17  121  2004-2020
# 2     Terrell Owens+  15934  1996-2010                  15  153  1996-2010
# 3        Randy Moss+  15292  1998-2012                  15  156  1998-2012
# 4       Isaac Bruce+  15208  1994-2009                  16   91  1994-2009

# %%
joined_QB_data['Position'] = 'QB'
joined_RB_data['Position'] = 'RB'
joined_WR_data['Position'] = 'WR'

# %% [markdown]
# ## Transfrom the Data

# %%
joined_QB_data['Performance-Index'] = (joined_QB_data['Yds'] /  joined_QB_data['Yds'].max()) * 50 + (joined_QB_data['TDs'] /  joined_QB_data['TDs'].max()) * 50
joined_RB_data['Performance-Index'] = (joined_RB_data['Yds'] /  joined_RB_data['Yds'].max()) * 50 + (joined_RB_data['TD'] /  joined_RB_data['TD'].max()) * 50
joined_WR_data['Performance-Index'] = (joined_WR_data['Yds'] /  joined_WR_data['Yds'].max()) * 50 + (joined_WR_data['TD'] /  joined_WR_data['TD'].max()) * 50

# %%
joined_QB_data.head()
# Out:
#             Player    Yds  year of draft  Unnamed: 3  Seasons in the NFL  TDs  \
# 0        Tom Brady  89214           2000        2022                  23  649
# 1      Drew Brees+  80358           2001        2020                  20  571
# 2  Peyton Manning+  71940           1998        2015                  18  539
# 3     Brett Favre+  71838           1991        2010                  20  508
# 4    Aaron Rodgers  66274           2005        2025                  21  527
#
#        Years Position Performance-Index
# 0  2000-2022       QB             100.0
# 1  2001-2020       QB         89.027408
# 2  1998-2015       QB         81.844208
# 3  1991-2010       QB         79.398752
# 4  2005-2025       QB         77.744198

# %% [markdown]
# ## Plot the data

# %%
pd.concat([joined_QB_data, joined_RB_data, joined_WR_data])
# Out:
#               Player    Yds  year of draft  Unnamed: 3  Seasons in the NFL  \
# 0          Tom Brady  89214         2000.0      2022.0                  23
# 1        Drew Brees+  80358         2001.0      2020.0                  20
# 2    Peyton Manning+  71940         1998.0      2015.0                  18
# 3       Brett Favre+  71838         1991.0      2010.0                  20
# 4      Aaron Rodgers  66274         2005.0      2025.0                  21
# ..               ...    ...            ...         ...                 ...
# 197      Eric Decker   5816            NaN         NaN                   8
# 198      Mike Ditka+   5812            NaN         NaN                  12
# 199      Riley Odoms   5755            NaN         NaN                  12
# 200     Roy Williams   5715            NaN         NaN                   8
# 201   John Jefferson   5714            NaN         NaN                   8
#
#      TDs      Years Position Performance-Index    Years_x    TD    Years_y
# 0    649  2000-2022       QB             100.0        NaN   NaN        NaN
# 1    571  2001-2020       QB         89.027408        NaN   NaN        NaN
# 2    539  1998-2015       QB         81.844208        NaN   NaN        NaN
# 3    508  1991-2010       QB         79.398752        NaN   NaN        NaN
# 4    527  2005-2025       QB         77.744198        NaN   NaN        NaN
# ..   ...        ...      ...               ...        ...   ...        ...
# 197  NaN        NaN       WR          26.15324  2010-2017  53.0  2010-2017
# 198  NaN        NaN       WR         23.606433  1961-1972  43.0  1961-1972
# 199  NaN        NaN       WR         22.974338  1972-1983  41.0  1972-1983
# 200  NaN        NaN       WR         23.648404  2004-2011  44.0  2004-2011
# 201  NaN        NaN       WR         24.407641  1978-1985  47.0  1978-1985
#
# [639 rows x 12 columns]

# %%
plt.scatter(joined_QB_data['Seasons in the NFL'], joined_QB_data['Performance-Index'])
plt.xlabel("Season in the NFL")
plt.ylabel("Performance Index")
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
joined_datas = pd.concat([joined_QB_data, joined_RB_data, joined_WR_data])

# %%
drafts_df = pd.read_csv('../drafts_2k_2k21.csv')

drafts_clean_exact = drafts_df.drop_duplicates(subset=['round', 'pick', 'team', 'name', 'pos', 'year', 'college'])

drafts_final_clean = drafts_clean_exact.drop_duplicates(subset=['name', 'pos'], keep='first')

final_df = pd.merge(
    joined_datas, 
    drafts_final_clean[['name', 'pos', 'pick']], 
    left_on=['Player', 'Position'],   
    right_on=['name', 'pos'],         
    how='left',
    validate='m:1' 
)

final_df = final_df.drop(columns=['name', 'pos'])

# %%
final_df[final_df['pick'].notna()]
# Out:
#                  Player    Yds  year of draft  Unnamed: 3  Seasons in the NFL  \
# 5      Matthew Stafford  64516         2009.0      2025.0                  17
# 6    Ben Roethlisberger  64088         2004.0      2021.0                  18
# 7         Philip Rivers  63984         2004.0      2025.0                  22
# 8             Matt Ryan  62792         2008.0      2022.0                  15
# 13           Joe Flacco  48176         2008.0      2025.0                  18
# ..                  ...    ...            ...         ...                 ...
# 621   Amon-Ra St. Brown   6252            NaN         NaN                   5
# 626           Lee Evans   6008            NaN         NaN                   8
# 632         James Jones   5861            NaN         NaN                   9
# 634         Eric Decker   5816            NaN         NaN                   8
# 637        Roy Williams   5715            NaN         NaN                   8
#
#      TDs      Years Position Performance-Index    Years_x    TD    Years_y  \
# 5    423  2009-2025       QB           68.7466        NaN   NaN        NaN
# 6    418  2004-2021       QB         68.121519        NaN   NaN        NaN
# 7    425  2004-2025       QB         68.602524        NaN   NaN        NaN
# 8    381  2008-2022       QB         64.544637        NaN   NaN        NaN
# 13   272  2008-2025       QB         47.955562        NaN   NaN        NaN
# ..   ...        ...      ...               ...        ...   ...        ...
# 621  NaN        NaN       WR         24.821149  2021-2025  44.0  2021-2025
# 626  NaN        NaN       WR         24.034474  2004-2011  43.0  2004-2011
# 632  NaN        NaN       WR           25.7439  2007-2015  51.0  2007-2015
# 634  NaN        NaN       WR          26.15324  2010-2017  53.0  2010-2017
# 637  NaN        NaN       WR         23.648404  2004-2011  44.0  2004-2011
#
#       pick
# 5      1.0
# 6     11.0
# 7      4.0
# 8      3.0
# 13    18.0
# ..     ...
# 621  112.0
# 626   13.0
# 632   78.0
# 634   87.0
# 637    7.0
#
# [142 rows x 13 columns]
